# %% [markdown]
# # 0. Libraries and setup

# %%
import pandas as pd
import numpy as np
import os
import chardet

# %%
# Set path to the directory containing the CSV files
data_path = '../data/'

# %% [markdown]
# # 1. Loading the data
#
# Source of the data: https://dataverse.harvard.edu/dataverse/crowdcountingconsortium
#
# The encoding of the data files isn't the standard one (UTF-8), so we must detect the type of encoding. To do so, we can use the library [`chardet`](https://chardet.readthedocs.io/en/latest/).

# %%
# Detect the encoding of the CSV file
# with open(os.path.join(data_path, 'dataverse_files_2017-2020', 'ccc_compiled_20172020.csv'), 'rb') as f:
#     result = chardet.detect(f.read()) 
# print(result)
# Out:
# {'encoding': 'MacRoman', 'confidence': 0.7292219720640579, 'language': ''}

# %%
encoding='ISO-8859-1'  # Adjust the encoding type of the CSV files if necessary ('ISO-8859-1' is common for Latin-1 encoded files)

df1 = pd.read_csv(
    os.path.join(data_path, 'dataverse_files_2017-2020', 'ccc_compiled_20172020.csv'), # From Jan 2017 to Dec 2020
    encoding='MacRoman',
    low_memory=False
)
df2 = pd.read_csv(
    os.path.join(data_path, 'dataverse_files_2021-2024', 'ccc_compiled_20212024.csv'), # From Jan 2021 to Dec 2024
    encoding='MacRoman',
    low_memory=False
)  
df3 = pd.read_csv(
    os.path.join(data_path, 'dataverse_files_2025_05_08-', 'ccc-phase3-public.csv'),  # From Jan 2025 to May 2025
    encoding='MacRoman',
    low_memory=False
)

# Save the dataframes in a dictionary
dfs = {
    '2017-2020': df1,
    '2021-2024': df2,
    '2025-': df3
}

# %%
df1.head()
# Out:
#          date        locality state                 location_detail  online  \
# 0  2017-01-01      Washington    DC           Lafayette Square Park     0.0
# 1  2017-01-01         Mankato    MN                             NaN     0.0
# 2  2017-01-01     Minneapolis    MN               U.S. Bank Stadium     0.0
# 3  2017-01-01  Little Compton    RI                      Town Green     0.0
# 4  2017-01-01       Oak Ridge    TN  Y-12 National Security Complex     0.0
#
#                    type macroevent                                  actors  \
# 0                 vigil        NaN                                     NaN
# 1                 vigil        NaN                     Peace Vigil Mankato
# 2  protest; banner drop        NaN                      general protestors
# 3                 vigil        NaN                 Sakonnet Peace Alliance
# 4                 vigil        NaN  Oak Ridge Environmental Peace Alliance
#
#                                               claims  valence  ... source_28  \
# 0             for banning nuclear weapons, for peace      0.0  ...       NaN
# 1                                          for peace      0.0  ...       NaN
# 2  against the Dakota Access Pipeline, for indige...      1.0  ...       NaN
# 3     for peace, for gun control, for climate action      1.0  ...       NaN
# 4                     for abolishing nuclear weapons      0.0  ...       NaN
#
#   source_29  source_30                                              notes  \
# 0       NaN        NaN  White House Peace Vigil continuous since June ...
# 1       NaN        NaN                            every Sunday since 2001
# 2       NaN        NaN      hung banner from stadium roof during NFL game
# 3       NaN        NaN                            every Sunday since 2003
# 4       NaN        NaN                  every Sunday since the late 1990s
#
#          lat        lon resolved_locality       resolved_county  \
# 0  38.907192 -77.036871        Washington  District of Columbia
# 1  44.163578 -93.999400           Mankato     Blue Earth County
# 2  44.977753 -93.265011       Minneapolis       Hennepin County
# 3  41.510103 -71.171156    Little Compton        Newport County
# 4  36.010356 -84.269645         Oak Ridge       Anderson County
#
#   resolved_state  fips_code
# 0             DC    11001.0
# 1             MN    27013.0
# 2             MN    27053.0
# 3             RI    44005.0
# 4             TN    47001.0
#
# [5 rows x 62 columns]

# %%
df2.head()
# Out:
#          date    locality state                    location_detail  online  \
# 0  2021-01-01  Montgomery    AL                          statewide     0.0
# 1  2021-01-01      Tucson    AZ   E Speedway Blvd and N Euclid Ave     0.0
# 2  2021-01-01   Lafayette    CA       El Curtola Blvd & Highway 24     0.0
# 3  2021-01-01   Palo Alto    CA  El Camino Real and Embarcadero Rd     0.0
# 4  2021-01-01    Pasadena    CA                  Rose Bowl Stadium     0.0
#
#               type                  title macroevent  \
# 0  strike; boycott                    NaN        NaN
# 1            vigil                    NaN        NaN
# 2    demonstration                    NaN        NaN
# 3            vigil                    NaN        NaN
# 4    rally; parade  Patriots' Rose Parade        NaN
#
#                       organizations      participants  ... source_28  \
# 0             Free Alabama Movement         prisoners  ...       NaN
# 1                    Women in Black               NaN  ...       NaN
# 2      Contra Costa County Patriots               NaN  ...       NaN
# 3                             WILPF               NaN  ...       NaN
# 4  Trump Unity Bridge SO CAL Events  Trump supporters  ...       NaN
#
#   source_29 source_30                                              notes  \
# 0       NaN       NaN                          Scheduled to run 30 days.
# 1       NaN       NaN  every Friday since at least 2001; organizers c...
# 2       NaN       NaN                                                NaN
# 3       NaN       NaN     every Friday; started in 1922, some gaps since
# 4       NaN       NaN                              Patriots' Rose Parade
#
#          lat         lon  resolved_locality      resolved_county  \
# 0  32.379223  -86.307737         Montgomery    Montgomery County
# 1  32.253979 -110.974177             Tucson          Pima County
# 2  37.885758 -122.118020          Lafayette  Contra Costa County
# 3  37.441883 -122.143019          Palo Alto   Santa Clara County
# 4  34.147785 -118.144515           Pasadena   Los Angeles County
#
#    resolved_state  fips_code
# 0              AL     1101.0
# 1              AZ     4019.0
# 2              CA     6013.0
# 3              CA     6085.0
# 4              CA     6037.0
#
# [5 rows x 72 columns]

# %%
df3.head()
# Out:
#        date     locality state resolved_locality resolved_state  \
# 0  1/1/2025       Albany    NY            Albany             NY
# 1  1/1/2025    Baltimore    MD         Baltimore             MD
# 2  1/1/2025       Bangor    ME            Bangor             ME
# 3  1/1/2025   Bellingham    WA        Bellingham             WA
# 4  1/1/2025  Bloomington    IN       Bloomington             IN
#
#     resolved_county  fips_code        lat         lon                location  \
# 0     Albany County    36001.0  42.652579  -73.756232   Albany Medical Center
# 1               NaN    24510.0  39.290385  -76.612189                  online
# 2  Penobscot County    23019.0  44.801613  -68.771226  Harlow St & Central St
# 3    Whatcom County    53073.0  48.751911 -122.478685  Railroad Trail and I-5
# 4     Monroe County    18105.0  39.165325  -86.526386          Dimension Mill
#
#    ... source21 source22 source23 source24 source25 source26 source27  \
# 0  ...      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1  ...      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2  ...      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3  ...      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4  ...      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#   source28 source29 source30
# 0      NaN      NaN      NaN
# 1      NaN      NaN      NaN
# 2      NaN      NaN      NaN
# 3      NaN      NaN      NaN
# 4      NaN      NaN      NaN
#
# [5 rows x 73 columns]

# %%
for key, df in dfs.items():
    print(f"DataFrame for {key}:\n")
    print(df.info())
    print("\n")
# Out:
# DataFrame for 2017-2020:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72181 entries, 0 to 72180
# Data columns (total 62 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 72181 non-null  object
#  1   locality             72162 non-null  object
#  2   state                72143 non-null  object
#  3   location_detail      63413 non-null  object
#  4   online               72142 non-null  float64
#  5   type                 71754 non-null  object
#  6   macroevent           1879 non-null   object
#  7   actors               66775 non-null  object
#  8   claims               72165 non-null  object
#  9   valence              72152 non-null  float64
#  10  issues               68594 non-null  object
#  11  size_text            29583 non-null  object
#  12  size_low             36073 non-null  float64
#  13  size_high            36050 non-null  float64
#  14  size_mean            36073 non-null  float64
#  15  size_cat             72181 non-null  int64
#  16  arrests              43701 non-null  object
#  17  arrests_any          72181 non-null  int64
#  18  injuries_crowd       43611 non-null  object
#  19  injuries_crowd_any   72181 non-null  int64
#  20  injuries_police      43622 non-null  object
#  21  injuries_police_any  72181 non-null  int64
#  22  property_damage      43668 non-null  object
#  23  property_damage_any  72181 non-null  int64
#  24  chemical_agents      12519 non-null  float64
#  25  source_1             72091 non-null  object
#  26  source_2             21041 non-null  object
#  27  source_3             5722 non-null   object
#  28  source_4             1347 non-null   object
#  29  source_5             744 non-null    object
#  30  source_6             408 non-null    object
#  31  source_7             225 non-null    object
#  32  source_8             286 non-null    object
#  33  source_9             77 non-null     object
#  34  source_10            54 non-null     object
#  35  source_11            36 non-null     object
#  36  source_12            27 non-null     object
#  37  source_13            13 non-null     object
#  38  source_14            8 non-null      object
#  39  source_15            5 non-null      object
#  40  source_16            5 non-null      object
#  41  source_17            8 non-null      object
#  42  source_18            0 non-null      float64
#  43  source_19            4 non-null      float64
#  44  source_20            0 non-null      float64
#  45  source_21            0 non-null      float64
#  46  source_22            0 non-null      float64
#  47  source_23            0 non-null      float64
#  48  source_24            0 non-null      float64
#  49  source_25            0 non-null      float64
#  50  source_26            0 non-null      float64
#  51  source_27            0 non-null      float64
#  52  source_28            0 non-null      float64
#  53  source_29            0 non-null      float64
#  54  source_30            0 non-null      float64
#  55  notes                17526 non-null  object
#  56  lat                  72149 non-null  float64
#  57  lon                  72149 non-null  float64
#  58  resolved_locality    71466 non-null  object
#  59  resolved_county      67667 non-null  object
#  60  resolved_state       72131 non-null  object
#  61  fips_code            72074 non-null  float64
# dtypes: float64(22), int64(5), object(35)
# memory usage: 34.1+ MB
# None
#
#
# DataFrame for 2021-2024:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139823 entries, 0 to 139822
# Data columns (total 72 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   date                  139823 non-null  object
#  1   locality              139770 non-null  object
#  2   state                 139807 non-null  object
#  3   location_detail       130019 non-null  object
#  4   online                139755 non-null  float64
#  5   type                  139774 non-null  object
#  6   title                 55460 non-null   object
#  7   macroevent            7700 non-null    object
#  8   organizations         101404 non-null  object
#  9   participants          35457 non-null   object
#  10  claims                139814 non-null  object
#  11  claims_summary        139152 non-null  object
#  12  claims_verbatim       42551 non-null   object
#  13  issue_tags_summary    136298 non-null  object
#  14  issue_tags_verbatim   34333 non-null   object
#  15  issue_tags            137452 non-null  object
#  16  valence               139789 non-null  float64
#  17  size_text             46938 non-null   object
#  18  size_low              47040 non-null   float64
#  19  size_high             47030 non-null   float64
#  20  size_mean             47040 non-null   float64
#  21  size_cat              139823 non-null  int64
#  22  arrests               1778 non-null    object
#  23  arrests_any           139823 non-null  int64
#  24  injuries_crowd        441 non-null     object
#  25  injuries_crowd_any    139823 non-null  int64
#  26  injuries_police       84 non-null      object
#  27  injuries_police_any   139823 non-null  int64
#  28  property_damage       788 non-null     object
#  29  property_damage_any   139823 non-null  int64
#  30  chemical_agents       139823 non-null  int64
#  31  participant_measures  37303 non-null   object
#  32  police_measures       10810 non-null   object
#  33  participant_deaths    19 non-null      object
#  34  police_deaths         2 non-null       object
#  35  source_1              139743 non-null  object
#  36  source_2              61307 non-null   object
#  37  source_3              28870 non-null   object
#  38  source_4              14444 non-null   object
#  39  source_5              7972 non-null    object
#  40  source_6              4840 non-null    object
#  41  source_7              3372 non-null    object
#  42  source_8              2098 non-null    object
#  43  source_9              1402 non-null    object
#  44  source_10             1054 non-null    object
#  45  source_11             814 non-null     object
#  46  source_12             640 non-null     object
#  47  source_13             514 non-null     object
#  48  source_14             420 non-null     object
#  49  source_15             360 non-null     object
#  50  source_16             293 non-null     object
#  51  source_17             246 non-null     object
#  52  source_18             206 non-null     object
#  53  source_19             176 non-null     object
#  54  source_20             138 non-null     object
#  55  source_21             114 non-null     object
#  56  source_22             88 non-null      object
#  57  source_23             69 non-null      object
#  58  source_24             61 non-null      object
#  59  source_25             48 non-null      object
#  60  source_26             43 non-null      object
#  61  source_27             37 non-null      object
#  62  source_28             30 non-null      object
#  63  source_29             27 non-null      object
#  64  source_30             23 non-null      object
#  65  notes                 80067 non-null   object
#  66  lat                   139762 non-null  float64
#  67  lon                   139762 non-null  float64
#  68  resolved_locality     139011 non-null  object
#  69  resolved_county       126277 non-null  object
#  70  resolved_state        139730 non-null  object
#  71  fips_code             139697 non-null  float64
# dtypes: float64(8), int64(6), object(58)
# memory usage: 76.8+ MB
# None
#
#
# DataFrame for 2025-:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11432 entries, 0 to 11431
# Data columns (total 73 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   date                        11432 non-null  object
#  1   locality                    11413 non-null  object
#  2   state                       11432 non-null  object
#  3   resolved_locality           11413 non-null  object
#  4   resolved_state              11432 non-null  object
#  5   resolved_county             10372 non-null  object
#  6   fips_code                   11055 non-null  float64
#  7   lat                         11052 non-null  float64
#  8   lon                         11052 non-null  float64
#  9   location                    10678 non-null  object
#  10  title                       6770 non-null   object
#  11  event_type                  11399 non-null  object
#  12  organizations               7685 non-null   object
#  13  participants                1340 non-null   object
#  14  notables                    451 non-null    object
#  15  targets                     5216 non-null   object
#  16  claims_summary              11425 non-null  object
#  17  claims_verbatim             3800 non-null   object
#  18  issue_tags_summary          11421 non-null  object
#  19  issue_tags_verbatim         3795 non-null   object
#  20  issues                      11423 non-null  object
#  21  valence                     11419 non-null  float64
#  22  conf                        5165 non-null   float64
#  23  macroevent                  360 non-null    object
#  24  online                      11432 non-null  int64
#  25  size_text                   4492 non-null   object
#  26  size_low                    4493 non-null   float64
#  27  size_high                   4487 non-null   float64
#  28  size_mean                   4487 non-null   float64
#  29  size_cat                    11432 non-null  int64
#  30  participant_measures        2713 non-null   object
#  31  police_measures             426 non-null    object
#  32  participant_injuries        15 non-null     object
#  33  police_injuries             0 non-null      float64
#  34  arrests                     68 non-null     object
#  35  property_damage             18 non-null     object
#  36  arrests_any                 11432 non-null  int64
#  37  participant_casualties_any  11432 non-null  int64
#  38  police_casualties_any       11432 non-null  int64
#  39  property_damage_any         11432 non-null  int64
#  40  participant_deaths          0 non-null      float64
#  41  police_deaths               0 non-null      float64
#  42  notes                       4381 non-null   object
#  43  source1                     11419 non-null  object
#  44  source2                     4654 non-null   object
#  45  source3                     1833 non-null   object
#  46  source4                     768 non-null    object
#  47  source5                     355 non-null    object
#  48  source6                     194 non-null    object
#  49  source7                     117 non-null    object
#  50  source8                     76 non-null     object
#  51  source9                     48 non-null     object
#  52  source10                    33 non-null     object
#  53  source11                    27 non-null     object
#  54  source12                    21 non-null     object
#  55  source13                    14 non-null     object
#  56  source14                    10 non-null     object
#  57  source15                    8 non-null      object
#  58  source16                    5 non-null      object
#  59  source17                    4 non-null      object
#  60  source18                    4 non-null      object
#  61  source19                    1 non-null      object
#  62  source20                    1 non-null      object
#  63  source21                    1 non-null      object
#  64  source22                    1 non-null      object
#  65  source23                    1 non-null      object
#  66  source24                    1 non-null      object
#  67  source25                    1 non-null      object
#  68  source26                    1 non-null      object
#  69  source27                    1 non-null      object
#  70  source28                    1 non-null      object
#  71  source29                    1 non-null      object
#  72  source30                    1 non-null      object
# dtypes: float64(11), int64(6), object(56)
# memory usage: 6.4+ MB
# None

# %% [markdown]
# # 2. Columns of interest
#
# Information extracted from the documentation of the data. Check out as well the [coding guidelines](https://docs.google.com/document/d/1oaOf9s72FQnzQA8sbE8h0PwMIZLP6p0EDUV2ya065is/edit?tab=t.0#heading=h.86aoh6qprspd) of the authors that they use whenever they need to do a judgement call (e.g., calling a demonstration pro-Trump or anti-Trump).
#
# **Columns in 2017-2020 (1st edition)**:
#
# - `date`: Date of event in YYYY-MM-DD format. When an event spans multiple days, the start date is used.
# - `locality`: Name of the locality in which the event took place. Labeled CityTown in the Google Sheets.
# - `state`: Two-letter U.S. postal abbreviation for the state or U.S. territory in which the event took place.
# - `location_detail`: Where available, text giving additional details on the location(s) within the city or town where the action took place.
# - `online`: Binary indicator for online-only events. 1 = online, 0 = in-person. Generated from location and event type information in the source data.
# - `type`: Type(s) of protest action (e.g. march, protest, demonstration, strike, counter-protest, sit-in), separated with semicolons or commas when more than one. EventType in source data.
# - `macroevent`: A unique id that associates a counter-protest with the protest event it countered. These strings are composed of a date, a location, and something about the nature of the event, all separated by hyphens (e.g., "20220624-phoenix-abortion"). In most cases, these ids will uniquely identify pairs of events. In cases where the counter-protest is itself countered, however—e.g., a community defense action in response to a protest targeting an LGBTQ+ pride festival—the additional events are given the same id, so these clusters will sometimes include three or more events.
#   - NOTE: This field was created in 2021, and it was only retroactively generated for events associated with the Black Lives Matter protest wave that began in May 2020. So, for CCC Phase 1 data, it is only useful for analysis of that specific subset.
# - `actors`: The organization(s) that organized the protest event (e.g. Women's March, Greenpeace, etc.), and/or the type of people participating (e.g., students, nurses). Usually separated by semicolons, sometimes by commas.
# - `claims`: A phrase or phrases describing what the event was about, based on the claims or demands the participants made (e.g. for women's rights, anti-Muslim Ban, against racism, etc.), as summarized by coders. Phrases are separated by semicolons in some records, commas in others.
# - `valence`: Political valence of the event. Labeled Pro(2)/Anti(1) in the source data.
#   - 2 = pro-Trump
#   - 1 = anti-Trump
#   - 0 = other/neither
# - `issues`: String of semicolon-separated tags identifying political issues (or themes) associated with the event (e.g., "democracy; women's rights" for events associated with the 2017 Women's March). These are generated after data compilation by running a series of regular expressions over the claims description text.
# - `size_text`: Words or phrases that journalists or eyewitnesses used to describe the size of the crowd at the protest event (e.g., “more than 100”, “dozens”, “about 50”)—or, in cases where no text descriptions were found but other sources gave information about crowd size, the alternative source used: “count pic” for photograph(s), “count vid” for video(s), “count FB” for Facebook, or “eyewitness” for eyewitness.
# - `size_low`: Lowest crowd size reported in, or estimated from, size_text. To convert vague text counts to numbers, the following three rules are always used for both `size_low` and `size_high` (see below).
#   1. For phrases with fudge words (e.g., “about”, “nealy” “approximately”, “maybe”), ignore the fudge word and treat the number that follows it as the count.
#   2. When unspecific multiples are given, assume the multiple is 2  (e.g., “hundreds” becomes 200, “thousands” becomes 2,000).
#   3. Assume “several” means 3 (e.g., “several dozen” becomes 36, “several thousand” becomes 3,000).
# - `size_high`: Highest crowd size reported in, or estimated from, size_text.
#   - When vague text counts are converted to numbers, the high and low estimates are assumed to be equivalent. For example, if the only information available about crowd size is a single report describing it as “hundreds”, 200 would be assigned to both size_low and size_high.
#   - If, however, one source described the crowd size as “hundreds” and another as “about 500”, then size_low would still be 200, but size_high would be 500.
# - `size_mean`: The mathematical average of size_low and size_high, rounded up to the nearest integer.
# - `size_cat`: Ordered categorical indicator of crowd size, representing orders of magnitude and derived from size_mean.
#   - 0 = unknown
#   - 1 = 1-99 (tens)
#   - 2 = 100-999 (hundreds)
#   - 3 = 1,000-9,999 (thousands)
#   - 4 = 10,000+ (tens of thousands)
# - `arrests`: Text, sometimes specifying the count of protesters reportedly arrested (e.g., “5”), sometimes a phrase indicating ambiguity about that count (e.g., "more than 5", "unclear", “unspecified”).
# - `arrests_any`: Binary indicator for whether or not any arrests occurred, derived from arrests. 1 = yes, 0 = no.
# - `injuries_crowd`: Text, sometimes giving a count of protesters reportedly injured (e.g., “5”), sometimes a phrase indicating ambiguity about that count (e.g., "more than 5", "unclear", “unspecified”).
# - `injuries_crowd_any`: Binary indicator for whether or not any protesters were reportedly injured, derived from injuries_crowd. 1 = yes, 0 = no.
# - `injuries_police`: Text, sometimes giving a count of police officers reportedly injured (e.g., “5”), sometimes a phrase indicating ambiguity about that count (e.g., "more than 5", "unclear", “unspecified”).
# - `injuries_police_any`: Binary indicator for whether or not any police officers were reportedly injured, derived from injuries_police. 1 = yes, 0 = no.
# - `property_damage`: Text, usually a binary indicator for whether or not any property damage occurred, sometimes a count or other number of unclear meaning, sometimes something else.
# - `property_damage_any`: Binary indicator for whether or not protesters reportedly caused any property damage, derived from property_damage. 1 = yes, 0 = no.
# - `chemical_agents`: Binary indicator for whether or not police or other state security forces used tear gas or other chemical irritants, such as pepper spray or pepper balls, on protesters. Labeled TearGas in the source data, but only available for May–December 2020.
# - `source_n`: URL of nth source, or description where the source is not a web page (e.g., “eyewitness”, “correspondence”).
# - `notes`: Miscellaneous additional information about the event as noted by the coder.
# - `lat`: Latitude of locality in which the event took place, as resolved by Google Maps Geocoding API. Note that this is not based on address or landmark-level information where that is given, only on the name of the city or town.
# - `lon`: Longitude of locality in which the event took place, as resolved by Google Maps Geocoding API. Note that this is not based on address or landmark-level information where that is given, only on the name of the city or town.
# - `resolved_locality`: Name of the locality in which the event occurred, as resolved by running the city or town name and state abbreviation through the Google Maps Geocoding API.
# - `resolved_state`: Postal abbreviation of the state or territory in which the event occurred, as resolved by the Google Maps Geocoding API.
# - `resolved_county`: Name of the county in which the event occurred, as resolved by running resolved_locality and resolved_state through the Google Maps Geocoding API.
# - `fips_code`: Five-digit FIPS code for the county (or LA parish or AK borough or independent city or DC or U.S. territory) given in resolved_county. See 'data-compilation/fips_for_county_function.r' for details on how these are generated using the 'tigris' package and some custom code to handle various exceptions.
#   - NOTE: When you load the data from the stored .csv, you will probably need to add leading zeros back to FIPS codes that have them, because your software will probably read that column as integers instead of strings. In R, you could do this with `ifelse(nchar(fips_code) == 4, paste0("0", fips_code), fips_code)`.
#
# **Columns and modifications in the 2nd edition**:
# - `title`: Title of action when one is given, usually on a flyer announcing the event.
# - `organizations`: Semicolon-separated names of organization(s) that participated in the event, including but not limited to organizers and endorsers (.e.g, “Fridays for Future New York; Extinction Rebellion New York; Greenfaith”).
# - `participants`: Semicolon-separated text descriptors of participants in the event, usually from press reports, sometimes recorded by coders based on photos or video (e.g., “students; faculty; staff; community members”).
# - `claims`: Comma-separated text phrases describing what the event was about.
# - `claims_summary`: Text phrase or comma-separated text phrases giving coder’s summary of the action’s main claims or demands. Each phrase should begin with either “for”, “against”, or “in [action word] [of/with/for]” (e.g., “in commemoration of…”, “in solidarity with…”, “in remembrance of…”). Generated programmatically from claims field, so there will be occasional errors of omission and commission due to typos and such.
# - `claims_verbatim`: Comma-separated verbatim text captures of claims made by event participants on signs, banners, t-shirts, and flags or as chants or shouts. Generated programmatically from claims field, so there will be occasional errors of omission and commission due to typos and such.
#   - Phrases that end with an exclamation point (e.g., “no justice no peace!”) are chants or shouts.
#   - Text inside square brackets (e.g., “[wire hanger ]”, “[watermelon]”) is a coder’s description of an image or symbol seen on a sign or banner.
#   - Flags are recorded as phrases ending in “flag” (e.g., “Confederate flag”, Gadsden flag”). National flags other than the U.S. flag are recorded as the name of the country followed by “flag” (e.g., “Israel flag”, “Mexico flag”). The American flag is usually recorded as “American flag”, sometimes as “U.S. flag”, “US flag”, or “USA flag”.
#   - When the same claim is seen more than once, only one instance of it is recorded here.
# - `issue_tags_summary`:
# - `issue_tags_verbatim`:
# - `issue_tags`:

# %%
# Count the number of observations with injuries in the crowd, police and property damage
df1_riot = df1[(df1['injuries_crowd_any'] == 1) & (df1['injuries_police_any'] == 1 & (df1['property_damage_any'] == 1))]

df1_riot
# Out:
#              date    locality state                 location_detail  online  \
# 107    2017-01-18  Washington    DC       Trump International Hotel     0.0
# 119    2017-01-19  Washington    DC             National Press Club     0.0
# 130    2017-01-20  Washington    DC                   National Mall     0.0
# 1005   2017-01-29    Portland    ME  Portland International Jetport     0.0
# 1041   2017-01-29    Portland    OR  Portland International Airport     0.0
# ...           ...         ...   ...                             ...     ...
# 71378  2020-12-12    Santa Fe    NM                  The Roundhouse     0.0
# 71777  2020-12-19     Buffalo    NY                  Niagara Square     0.0
# 71807  2020-12-20     Rocklin    CA        Destiny Christian Church     0.0
# 71873  2020-12-21     McAllen    TX                     The Monitor     0.0
# 71874  2020-12-21     McAllen    TX                     The Monitor     0.0
#
#                   type                     macroevent  \
# 107            protest                            NaN
# 119    counter-protest                            NaN
# 130    counter-protest                            NaN
# 1005     demonstration                            NaN
# 1041     demonstration                            NaN
# ...                ...                            ...
# 71378  counter-protest  20201212-santafe-stopthesteal
# 71777  counter-protest         20201219-buffalo-covid
# 71807          protest   20201220-rocklin-covidchurch
# 71873            rally         20201221-mcallen-trump
# 71874  counter-protest         20201221-mcallen-trump
#
#                                      actors  \
# 107                       general protestor
# 119                      general protestors
# 130                      general protestors
# 1005                     general protestors
# 1041                     general protestors
# ...                                     ...
# 71378                    general protesters
# 71777                    general protesters
# 71807  Allies for Black Lives-Placer County
# 71873                    general protesters
# 71874                    general protesters
#
#                                                   claims  valence  ...  \
# 107       against election of Donald Trump to presidency      1.0  ...
# 119                           in support of Donald Trump      2.0  ...
# 130           for election of Donald Trump to presidency      2.0  ...
# 1005       end the "Muslim ban"; immigration; anti-Trump      1.0  ...
# 1041                 Protest immigration ban; anti-Trump      1.0  ...
# ...                                                  ...      ...  ...
# 71378  against President Trump, against fascism, agai...      1.0  ...
# 71777  in memory of victims of COVID-19, for free hea...      1.0  ...
# 71807  against church's defiance of COVID-related pub...      1.0  ...
# 71873        for President Trump, against election fraud      2.0  ...
# 71874                            against President Trump      1.0  ...
#
#       source_28 source_29  source_30  \
# 107         NaN       NaN        NaN
# 119         NaN       NaN        NaN
# 130         NaN       NaN        NaN
# 1005        NaN       NaN        NaN
# 1041        NaN       NaN        NaN
# ...         ...       ...        ...
# 71378       NaN       NaN        NaN
# 71777       NaN       NaN        NaN
# 71807       NaN       NaN        NaN
# 71873       NaN       NaN        NaN
# 71874       NaN       NaN        NaN
#
#                                                    notes        lat  \
# 107                                                  NaN  38.907192
# 119                                                  NaN  38.907192
# 130                                                  NaN  38.907192
# 1005                                                 NaN  43.659099
# 1041                                                 NaN  45.515232
# ...                                                  ...        ...
# 71378  verbal clashes and at least one physical fight...  35.686975
# 71777  placed trash bags as mock body bags during dem...  42.886447
# 71807                                                NaN  38.790734
        issues = issue.split(';')  # Split the issues by semicolon
        for i in issues:
            issues_1.add(i.strip())  # Add each issue to the set, stripping whitespace

# Do the same for the 2021-2024 dataset
unique_issues_2 = df2['issue_tags'].unique()

issues_2 = set()  # Initialize an empty set to store unique issues

# Store unique issues in the set, ignoring NaN values and separating by semicolons
for issue in unique_issues_2:
    if pd.notna(issue):  # Check if the issue is not NaN
        issues = issue.split(';')  # Split the issues by semicolon
        for i in issues:
            issues_2.add(i.strip())  # Add each issue to the set, stripping whitespace

# Do the same for the 2025 dataset
unique_issues_3 = df3['issues'].unique()

issues_3 = set()  # Initialize an empty set to store unique issues

# Store unique issues in the set, ignoring NaN values and separating by semicolons
for issue in unique_issues_3:
    if pd.notna(issue):  # Check if the issue is not NaN
        issues = issue.split(';')  # Split the issues by semicolon
        for i in issues:
            issues_3.add(i.strip())  # Add each issue to the set, stripping whitespace

print(issues_1)
print(issues_2)
print(issues_3)
# Out:
# {'policing', 'democracy', 'healthcare', "women's rights", 'immigration', 'patriotism', 'environment', 'education', 'reproductive rights', 'foreign affairs', 'disability rights', 'civil rights', 'covid', 'lgbtqia', 'labor', 'indigenous peoples', 'free speech', 'housing', 'transportation', 'racism', 'corruption', 'economy', 'banking and finance', 'guns', 'religion', 'science', 'sports', 'animal rights', 'legislative', 'judiciary', 'military', 'development', 'criminal justice', 'sexual violence', 'presidency', 'taxes', 'drugs', 'energy'}
# {'policing', 'democracy', 'healthcare', "women's rights", 'immigration', 'patriotism', 'environment', 'education', 'reproductive rights', 'foreign affairs', 'disability rights', 'civil rights', 'covid', 'lgbtqia', 'labor', 'indigenous peoples', 'housing', 'transportation', 'racism', 'corruption', 'economy', 'banking and finance', 'religion', 'guns', 'science', 'sports', 'drugs', 'animal rights', 'legislative', 'judiciary', 'military', 'criminal justice', 'development', 'sexual violence', 'presidency', 'taxes', 'free speech', 'energy'}
# {'policing', 'democracy', 'healthcare', "women's rights", 'patriotism', 'immigration', 'environment', 'education', 'reproductive rights', 'foreign affairs', 'disability rights', 'civil rights', 'covid', 'lgbtqia', 'indigenous peoples', 'housing', 'transportation', 'racism', 'corruption', 'economy', 'banking and finance', 'religion', 'science', 'guns', 'sports', 'drugs', 'animal rights', 'legislative', 'judiciary', 'criminal justice', 'labor and workers rights', 'sexual violence', 'war and peace', 'presidency', 'taxes', 'free speech', 'local development', 'energy'}

# %%
# Find the intersection of issues between the three datasets
intersection_issues = issues_1.intersection(issues_2).intersection(issues_3)

print("Intersection of issues between the three datasets:")
for issue in intersection_issues:
    print(issue)
# Out:
# Intersection of issues between the three datasets:
# policing
# democracy
# healthcare
# women's rights
# patriotism
# immigration
# environment
# education
# reproductive rights
# foreign affairs
# disability rights
# civil rights
# covid
# lgbtqia
# indigenous peoples
# free speech
# housing
# transportation
# racism
# corruption
# economy
# banking and finance
# religion
# science
# guns
# sports
# animal rights
# legislative
# judiciary
# criminal justice
# sexual violence
# presidency
# taxes
# drugs
# energy

# %% [markdown]
# Topics:
# - healthcare
# - racism + immigration
# - guns + criminal justice?
